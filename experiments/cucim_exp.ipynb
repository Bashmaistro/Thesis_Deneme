# %%
import pydicom

ds = pydicom.dcmread("data/islenen_dicomlar_astro/TCGA-CS-4938_e52d4d8b-3adc-4bf3-a04d-7f3daafac4bd.dcm")


ds_pixeldata = ds.pixel_array

print(ds_pixeldata.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pydicom
# ----> 3 ds = pydicom.dcmread("data/islenen_dicomlar_astro/TCGA-CS-4938_e52d4d8b-3adc-4bf3-a04d-7f3daafac4bd.dcm")
#       6 ds_pixeldata = ds.pixel_array
#       8 print(ds_pixeldata.shape)
#
# File ~/miniconda3/envs/mri-transfer-learning/lib/python3.9/site-packages/pydicom/filereader.py:1002, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1000     caller_owns_file = False
#    1001     logger.debug("Reading file '{0}'".format(fp))
# -> 1002     fp = open(fp, 'rb')
#    1003 elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#    1004     raise TypeError("dcmread: Expected a file path or a file-like, "
#    1005                     "but got " + type(fp).__name__)
#
# ...

# %%
import pydicom as pd

from white_filter import process_dcm_file

image = process_dcm_file(dcm_path="example.dcm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       1 import pydicom as pd
#       3 from white_filter import process_dcm_file
# ----> 5 image = process_dcm_file(dcm_path="example.dcm")
#
# File ~/Desktop/thesis/Thesis_Deneme/experiments/../src/utils/white_filter.py:11, in process_dcm_file(dcm_path, white_threshold)
#       8 def process_dcm_file(dcm_path , white_threshold=0.7):
# ---> 11     ds = pydicom.dcmread(dcm_path)
#      13     # NumberOfFrames
#      14     n_frames = int(ds.get("NumberOfFrames", 1))
#
# NameError: name 'pydicom' is not defined

# %%
# Out:
# [[[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 246 244]
#   [244 246 244]
#   [244 246 244]]
#
#  [[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 246 244]
#   [244 246 244]
#   [244 246 244]]
#
#  [[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 246 244]
#   [244 246 244]
#   [244 246 244]]
#
#  ...
#
#  [[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 244 244]
#   [244 244 244]
#   [244 244 244]]
#
#  [[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 244 244]
#   [244 244 244]
#   [244 244 244]]
#
#  [[244 244 244]
#   [244 244 244]
#   [244 244 244]
#   ...
#   [244 244 244]
#   [244 244 244]
#   [244 244 244]]]

# %%
# Out:
# b'\x00\x02*\xa8APPL\x02@\x00\x00scnrRGB Lab \x07\xd7\x00\n\x00\x0f\x00\x0e\x00\x1e\x00\x02acspMSFT\x00\x00\x00\x00        \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-LOGO\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x13cprt\x00\x00\x01h\x00\x00\x00*DevD\x00\x00\x01\x94\x00\x008\xc3CIED\x00\x00:X\x00\x00Zpchad\x00\x00\x94\xc8\x00\x00\x00,rXYZ\x00\x00\x94\xf4\x00\x00\x00\x14gXYZ\x00\x00\x95\x08\x00\x00\x00\x14bXYZ\x00\x00\x95\x1c\x00\x00\x00\x14wtpt\x00\x00\x950\x00\x00\x00\x14bkpt\x00\x00\x95D\x00\x00\x00\x14A2B0\x00\x00\x95X\x00\x01\x86^A2B2\x00\x00\x95X\x00\x01\x86^A2B1\x00\x00\x95X\x00\x01\x86^gmps\x00\x02\x1b\xb8\x00\x00\x00\xc4rTRC\x00\x02\x1c|\x00\x00\x04\ngTRC\x00\x02 \x88\x00\x00\x04\nbTRC\x00\x02$\x94\x00\x00\x04\nPmtr\x00\x02(\xa0\x00\x00\x01OLPIN\x00\x02)\xf0\x00\x00\x00Odesc\x00\x02*@
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 # TIFF dosyasını oku
#       4 img_path = "output.tiff"
# ----> 5 img = cucim.clara.CuImage(img_path)
#       7 # Görüntü boyutları
#       8 print("Width:", img.width)
#
# RuntimeError: This format has more than one image with Subfile Type 0 so cannot be loaded!
